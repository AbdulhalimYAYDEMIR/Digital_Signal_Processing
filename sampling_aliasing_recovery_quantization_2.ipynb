# %%
# Abdülhalim YAYDEMİR

# %% [markdown]
# ### SORU-2

# %% [markdown]
# ## a)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

Fs=1000
Ts=1/Fs
N=22
n=np.arange(0.,2*N)
xn1=7*np.cos(200*np.pi*n*Ts)
xn2=3*np.cos(200*np.pi*n*Ts)+4*np.cos(1800*np.pi*n*Ts)

plt.figure()
plt.stem(n,xn1)
plt.title("x1[n]")
plt.xlabel("örnek")
plt.ylabel("x1[n]")
plt.show()

plt.figure()
plt.stem(n,xn2)
plt.title("x2[n]")
plt.xlabel("örnek")
plt.ylabel("x2[n]")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Fs ikinici işaretin Nyquist şartına uymadığından doğru örnekleme yapılamamı ve birinci işarete benzemiştir

# %% [markdown]
# ## b)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import scipy.signal as sig
from scipy.fftpack import fft, ifft




Fs=1000
Ts=1/Fs
N=22
n=np.arange(0.,2*N)
xn1=7*np.cos(200*np.pi*n*Ts)
xn2=3*np.cos(200*np.pi*n*Ts)+4*np.cos(1800*np.pi*n*Ts)

w=np.linspace(-np.pi,np.pi-(2*np.pi/N),N)
x_w1=np.fft.fft(xn1,N)/N
x_w1=np.fft.fftshift(x_w1)
    
plt.figure()
plt.subplot(1,2,1)
plt.stem(w,np.abs(x_w1))
plt.title("X1(w)'nın Genlik Grafiği")
plt.xlabel("w")
plt.show()

plt.subplot(1,2,2)
plt.stem(w,np.angle(x_w1))
plt.title("X1(w)'nın Faz Grafiği")
plt.xlabel("w")
plt.show()
    

x_w2=np.fft.fft(xn2,N)/N
x_w2=np.fft.fftshift(x_w2)
    
plt.figure()
plt.subplot(1,2,1)
plt.stem(w,np.abs(x_w2))
plt.title("X2(w)'nın Genlik Grafiği")
plt.xlabel("w")
plt.show()

plt.subplot(1,2,2)
plt.stem(w,np.angle(x_w2))
plt.title("X2(w)'nın Faz Grafiği")
plt.xlabel("w")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### İki işaretin örneklemeleri aynı çıktığından fourier transformlarıda aynıdır.

# %% [markdown]
# ## c)

# %% [markdown]
# ## ?

# %% [markdown]
# ### Soru-3

# %% [markdown]
# ## a)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

F=4800
T=1/F

t=np.arange(0.,3*T,0.000000001)
x=np.sin(9600*np.pi*t)

plt.figure()
plt.xlabel("t")
plt.title("x3(t)=sin(9600*np.pi*t)")
plt.plot(t,x)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## b)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

Fs=8192
Ts=1/Fs
N=128
n=np.arange(0.,3*N)
xn3=np.sin(9600*np.pi*n*Ts)

plt.figure()
plt.stem(n,xn3)
plt.title("x3[n]")
plt.xlabel("örnek")
plt.ylabel("x3[n]")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## c)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import scipy.signal as sig
from scipy.fftpack import fft, ifft




Fs=8192
Ts=1/Fs
N=128
n=np.arange(0.,3*N)
xn1=np.sin(9600*np.pi*n*Ts)


w=np.linspace(-np.pi,np.pi-(2*np.pi/N),N)
x_w1=np.fft.fft(xn1,N)/N
x_w1=np.fft.fftshift(x_w1)
    
plt.figure()
plt.subplot(1,2,1)
plt.stem(w,np.abs(x_w1))
plt.title("X3(w)'nın Genlik Grafiği")
plt.xlabel("w")
plt.show()

plt.subplot(1,2,2)
plt.stem(w,np.angle(x_w1))
plt.title("X3(w)'nın Faz Grafiği")
plt.xlabel("w")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## d)

# %% [markdown]
# #### w= -2.60 ve +2.60 da 0.5 değeri alıyor ve bu frekanslarda fazı -pi/2 ve +pi/2
# #### Q=wFs=-+2.60*8192 , Q=2piF , F=-+3390 Hz
# ### x3(t)= -1sin(2pi3390t)   Yanlış elde ettik Nyquist şartı sağlanmadığından dolayı.

# %% [markdown]
# ## e)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

Fs=8192
Ts=1/Fs
N=128
n=np.arange(0.,3*N)
xn3=np.sin(9600*np.pi*n*Ts)
xn4=np.sin(6780*np.pi*n*Ts)

plt.figure()
plt.stem(n,xn3)
plt.title("x3[n]")
plt.xlabel("örnek")
plt.ylabel("x3[n]")
plt.show()

plt.figure()
plt.stem(n,xn4)
plt.title("x4[n]")
plt.xlabel("örnek")
plt.ylabel("x4[n]")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### işaretler tam olarak aynı değildir ama çoğu indisde değerler çok yakın

# %% [markdown]
# ### soru-4

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

n=np.arange(0,9)
xn=np.array([1.25,3.5,4,6.7,-1.4,-3.5,-10.5,8.5,3.8])
    
def quantize(x,S):
    X=x.reshape((-1,1))
    S=S.reshape((1,-1))
    dists = abs(X-S)
    nearestIndex = dists.argmin(axis=1)
    quantized = S.flat[nearestIndex]
    
    return quantized.reshape(x.shape)
    
k_bit=3
Max_range=np.amax(xn)-np.amin(xn)
q=pow(2,k_bit)
delta=Max_range/q
S_midrise=-np.amax(xn) + delta/2 + np.arange(q)*delta
S_midtread= -np.amax(xn) + np.arange(q)*delta
y_midtrise= quantize(xn, S_midrise)
y_midtread=quantize(xn,S_midtread)
    
fig,ax = plt.subplots()
ax.stem(n,xn)
ax.bar(n,y_midtrise, color='orange',edgecolor="darkorange")
plt.xlabel("örnek")
plt.title('midrise yöntemiyle kuantalanmış işaret')
    
fig, ax = plt.subplots()
ax.stem(n,xn)
ax.bar(n,y_midtread,color='orange', edgecolor="darkorange")
plt.xlabel("örnek")
plt.title("midtread yöntemiyle kuantalanmış işaret")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
