# %%
'''
Abdülhalim YAYDEMİR
'''
# DSP environment' da numpy ve matplotlib paketleri mevcut değil onlar anaconda üzerinden eklendi 
import numpy as np 
import matplotlib.pyplot as plt           
# %matplotlib notebook                     


# pi sayısını pi de sakla                             
pi = np.pi 


# gözlemlenecek aralığı belirle
n = np.arange(-46,46,1) 


# x[n] = sin(pi*n/19)
discrete = np.sin(pi*n/19)


# sinyal çizdirildi
plt.stem(n, discrete,'b-')
plt.title('x[n]')
plt.xlabel('n')
plt.grid(True)
plt.annotate('N = 38 ÖRNEK', xy=(11, 1), xytext=(-51, 1.02), arrowprops=dict(facecolor='red', shrink=0.05))

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
