# %%
# Abdülhalim YAYDEMİR

# %% [markdown]
# ### EK

# %% [markdown]
# ### SORU-2

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.fftpack import fft, ifft

x=np.array([0,0.707106,-1,0.707106,0,-0.707106,1,-0.707106])
N=len(x)
n=np.arange(0,8)

w_disc=n*2*np.pi/N                              # 0-2pi arasında (2pi noktası dahil değil) 2pi/4 adımlı vektör
X_abs=np.abs(fft(x)/N)
X_phase=np.angle(fft(x)/N)

plt.figure()
plt.subplot(121)
plt.stem(w_disc/np.pi,X_abs)
plt.xlabel('$\omega (\\times \pi)$')
plt.title('$\\frac{1} {N} |X(e^{j\omega})|=|a_{k}|$')

plt.subplot(122)
plt.stem(w_disc/np.pi,X_phase/np.pi)
plt.xlabel('$\omega (\\times \pi)$')
plt.title('$\\frac{1} {N}\measuredangle X(e^{j\omega}) (\\times \pi) =\measuredangle a_k(\\times \pi)$')
# Out:
# Text(0.5, 1.0, '$\\frac{1} {N}\\measuredangle X(e^{j\\omega}) (\\times \\pi) =\\measuredangle a_k(\\times \\pi)$')

# %% [markdown]
# ###### İşaret   :  cos⁡( 3π/4 - π/2 )
# ######  A    =     1
# ###### W0  =  3π/4
# ###### ∅     =  - π/2

# %% [markdown]
# ### SORU-3

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig
# %matplotlib notebook



w_cont=np.arange(0,2*np.pi,np.pi/1000)

H_abs=np.abs(2*np.sin(w_cont/2))
H_phase=(-w_cont/2) + (np.pi/2)             #np.angle(np.exp(1j*((-w_cont/2)+(np.pi/2))))

plt.figure()
plt.subplot(121)
plt.plot(w_cont/np.pi,H_abs)
plt.title('$|H(e^{j\omega})|$')
plt.xlabel('Normalize frekans (x$\pi$)')

plt.subplot(122)
plt.plot(w_cont/np.pi,H_phase/np.pi)
plt.title('$ \measuredangle H(e^{j\omega}) (\\times \pi)$')
plt.xlabel('Normalize frekans (x$\pi$)')






n = np.arange(0,11)
y = 0.999*np.cos((np.pi*n/3)+1.0477)

plt.figure()
plt.stem(n,y)
plt.title('y[n]')
plt.xlabel('n')

print('Genlik (w=pi/3) :',np.abs(2*np.sin(0.333*np.pi/2)))      #0.999
print('Faz (w=pi/3)    :',(-0.333*np.pi/2) + (np.pi/2))         #1.0477
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Genlik (w=pi/3) : 0.9990929632814857
# Faz (w=pi/3)    : 1.0477211499721961

# %% [markdown]
# ## Genlik (w = pi/3) : 0.9990929632814857
# ## Faz      (w = pi/3)    : 1.0477211499721961
