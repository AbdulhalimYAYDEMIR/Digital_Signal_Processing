# %%
# Abdülhalim YAYDEMİR

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sgnl
# %matplotlib notebook

'''
b = np.array([5,5,1.25])
a = np.array([1,-7.0/12, 1.0/12,0])
z,p,k=sgnl.tf2zpk(b,a)
print("sıfırlar, z:",z)
print("kutuplar, p:", p)
print("kazanc,   k:",k)

b = np.array([5])
a = np.array([1,-1.0/3])
z,p,k=sgnl.tf2zpk(b,a)
print("sıfırlar, z:",z)
print("kutuplar, p:", p)
print("kazanc,   k:",k)

b = np.array([5])
a = np.array([1,-1.0/3,0])
z,p,k=sgnl.tf2zpk(b,a)
print("sıfırlar, z:",z)
print("kutuplar, p:", p)
print("kazanc,   k:",k)

b = np.array([5,-5/2])
a = np.array([1,-1/3,0,0])
z,p,k=sgnl.tf2zpk(b,a)
print("sıfırlar, z:",z)
print("kutuplar, p:", p)
print("kazanc,   k:",k)

b = np.array([5,-5/2,0])
a = np.array([1,-10/21,1/21])
z,p,k=sgnl.tf2zpk(b,a)
print("sıfırlar, z:",z)
print("kutuplar, p:", p)
print("kazanc,   k:",k)

###

k = 5
z = np.array([-0.5,-0.5])
p = np.array([0,1.0/3,1.0/4])
b,a =sgnl.zpk2tf(z,p,k)
print("pay, b:", b)
print("payda, a:",a)

k = 5
z = np.array([])
p = np.array([1.0/3])
b,a =sgnl.zpk2tf(z,p,k)
print("pay, b:", b)
print("payda, a:",a)

k = 5
z = np.array([])
p = np.array([0,1.0/3])
b,a =sgnl.zpk2tf(z,p,k)
print("pay, b:", b)
print("payda, a:",a)

k = 5
z = np.array([1.0/2])
p = np.array([0,0,1.0/3])
b,a =sgnl.zpk2tf(z,p,k)
print("pay, b:", b)
print("payda, a:",a)

k = 5
z = np.array([0,1.0/2])
p = np.array([1.0/3,1.0/7])
b,a =sgnl.zpk2tf(z,p,k)
print("pay, b:", b)
print("payda, a:",a)

###

b = np.array([1,2,1])
a = np.array([1,-3/2,1/2])
z,p,k = sgnl.residuez(b,a)
print("kesir katsayıları, z:",z)
print("kutuplar, p:",p)
print("polinom, k:",k)

b = np.array([1])
a = np.array([1,-3/4,1/8])
z,p,k = sgnl.residuez(b,a)
print("kesir katsayıları, z:",z)
print("kutuplar, p:",p)
print("polinom, k:",k)

b = np.array([5,1,4,3])
a = np.array([1,-3])
z,p,k = sgnl.residuez(b,a)
print("kesir katsayıları, z:",z)
print("kutuplar, p:",p)
print("polinom, k:",k)

b = np.array([-11,16,-7])
a = np.array([1,-4/3,7/12,-1/12])
z,p,k = sgnl.residuez(b,a)
print("kesir katsayıları, z:",z)
print("kutuplar, p:",p)
print("polinom, k:",k)

b = np.array([1])
a = np.array([1,-3/4,0,1/16])
z,p,k = sgnl.residuez(b,a)
print("kesir katsayıları, z:",z)
print("kutuplar, p:",p)
print("polinom, k:",k)


#####
ODEV SORUSU ?
#####


b = np.array([0,5,5,1.25])
a = np.array([1,-7/12,1/12])
z,p,k = sgnl.residuez(b,a)
print("kesir katsayıları, z:",z)
print("kutuplar, p:",p)
print("polinom, k:",k)

###

b = np.array([0,5,5,1.25])
a = np.array([1,-7.0/12,1.0/12,0])
w ,h = sgnl.freqz(b,a)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w/np.pi,20*np.log10(abs(h)),'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample] x $\pi$')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w/np.pi,angles/np.pi,'g')
ax2.set_ylabel('Angle (radians) x $\pi$', color='g')
ax2.grid()
ax2.axis('tight')
plt.show()

b = np.ones(5)/5
a = np.array([1])
w ,h = sgnl.freqz(b,a)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w/np.pi,20*np.log10(abs(h)),'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample] x $\pi$')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w/np.pi,angles/np.pi,'g')
ax2.set_ylabel('Angle (radians) x $\pi$', color='g')
ax2.grid()
ax2.axis('tight')
plt.show()
b = np.ones(25)/25
a = np.array([1])
w ,h = sgnl.freqz(b,a)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w/np.pi,20*np.log10(abs(h)),'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample] x $\pi$')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w/np.pi,angles/np.pi,'g')
ax2.set_ylabel('Angle (radians) x $\pi$', color='g')
ax2.grid()
ax2.axis('tight')
plt.show()

b = np.array([1,-1])
a = np.array([1])
w ,h = sgnl.freqz(b,a)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w/np.pi,abs(h),'b')
ax1.set_ylabel('Amplitude', color='b')
ax1.set_xlabel('Frequency [rad/sample] x $\pi$')
plt.show()

b = np.array([1,-1,1,-1,1,-1,1,-1])
a = np.array([1])
w ,h = sgnl.freqz(b,a)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w/np.pi,abs(h),'b')
ax1.set_ylabel('Amplitude', color='b')
ax1.set_xlabel('Frequency [rad/sample] x $\pi$')
plt.show()

###

k = 5
z = np.array([-0.5,-0.5])
p = np.array([0,1.0/3,1.0/4])
w ,h = sgnl.freqz_zpk(z,p,k)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w/np.pi,abs(h),'b')
ax1.set_ylabel('Amplitude', color='b')
ax1.set_xlabel('Frequency [rad/sample] x $\pi$')
plt.show()

k = 5
z = np.array([])
p = np.array([1.0/3])
w ,h = sgnl.freqz_zpk(z,p,k)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w/np.pi,abs(h),'b')
ax1.set_ylabel('Amplitude', color='b')
ax1.set_xlabel('Frequency [rad/sample] x $\pi$')
plt.show()

k = 5
z = np.array([1.0/2])
p = np.array([0,0,1.0/3])
w ,h = sgnl.freqz_zpk(z,p,k)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w/np.pi,abs(h),'b')
ax1.set_ylabel('Amplitude', color='b')
ax1.set_xlabel('Frequency [rad/sample] x $\pi$')
plt.show()

k = 5
z = np.array([0,1/2])
p = np.array([1/3,1/7])
w ,h = sgnl.freqz_zpk(z,p,k)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w/np.pi,abs(h),'b')
ax1.set_ylabel('Amplitude', color='b')
ax1.set_xlabel('Frequency [rad/sample] x $\pi$')
plt.show()

###
 
z = np.array([0])
p = np.array([1.0/4,1.0/2])
b,a = sgnl.zpk2tf(z,p,1)
b,a
a = sgnl.convolve(np.array([1,-1/4]),np.array([1,-1/2]))
a
r,p,k = sgnl.residuez(b,a)
r,p,k
poless = np.roots(a)

###

num = np.array([1,0,0])
denum = np.array([1,-3.0/4,1.0/8])
n,x = sgnl.dimpulse((num,denum,1),x0=0,n=10)
x
plt.stem(n,np.squeeze(x))

###

n = np.arange(0,10,1)
xpf = -(1.0/4)**n + 2*(1.0/2)**n
num = np.array([1,0,0])
denum = np.array([1,-3.0/4, 1.0/8])
n1,xpse = sgnl.dimpulse((num,denum,1),x0=0,n=10)
xpse = np.squeeze(xpse)
plt.subplot(2,1,1), plt.stem(n,xpf),plt.ylabel('$x_{pf}[n]$')
plt.subplot(2,1,2), plt.stem(n, xpse),plt.ylabel('x_{pse}[n]$')
plt.xlabel('index vector (sample)')

###

zeros = np.array([-1])
poles = np.array([1j/2, -1j/2, 1.0/4])
w,H = sgnl.freqz_zpk(zeros,poles,1)
plt.plot(w/np.pi, abs(H))
plt.title('Frequency Response of $H(z)$')
plt.ylabel('Magnitude'), plt.xlabel('$\omega$ x $\pi$ (rad/sample)')
plt.grid()
n = np.arange(0,40,1)
xn = 2*np.cos(0.2*np.pi*n) + np.sin(0.9*np.pi*n)
yn = sgnl.lfilter(num,denum,xn)
plt.figure()
plt.stem(n,yn)

###

zeross = np.array([-1])
poless = np.array([-1j/2,1j/2,-1/4])
k=1
b,a=sgnl.zpk2tf(zeross,poless,k)
zplane(b,a)
num = np.array([1,0,1])
denum = np.array([1,-1.0/2])
plt.figure()
zplane(num,denum)
w = np.linspace(0,2*np.pi,100)
Hw= (1+np.exp(-2*1j*w))/(1-(1/2)*np.exp(-1j*w))
Hw_abs=abs(Hw)
plt.figure()
plt.plot(w/np.pi,Hw_abs)
plt.grid()
plt.xlabel('$\omega$ x$\pi$ rad/sample')
'''
# Out:
# '\nb = np.array([5,5,1.25])\na = np.array([1,-7.0/12, 1.0/12,0])\nz,p,k=sgnl.tf2zpk(b,a)\nprint("sıfırlar, z:",z)\nprint("kutuplar, p:", p)\nprint("kazanc,   k:",k)\n\nb = np.array([5])\na = np.array([1,-1.0/3])\nz,p,k=sgnl.tf2zpk(b,a)\nprint("sıfırlar, z:",z)\nprint("kutuplar, p:", p)\nprint("kazanc,   k:",k)\n\nb = np.array([5])\na = np.array([1,-1.0/3,0])\nz,p,k=sgnl.tf2zpk(b,a)\nprint("sıfırlar, z:",z)\nprint("kutuplar, p:", p)\nprint("kazanc,   k:",k)\n\nb = np.array([5,-5/2])\na = np.array([1,-1/3,0,0])\nz,p,k=sgnl.tf2zpk(b,a)\nprint("sıfırlar, z:",z)\nprint("kutuplar, p:", p)\nprint("kazanc,   k:",k)\n\nb = np.array([5,-5/2,0])\na = np.array([1,-10/21,1/21])\nz,p,k=sgnl.tf2zpk(b,a)\nprint("sıfırlar, z:",z)\nprint("kutuplar, p:", p)\nprint("kazanc,   k:",k)\n\n###\n\nk = 5\nz = np.array([-0.5,-0.5])\np = np.array([0,1.0/3,1.0/4])\nb,a =sgnl.zpk2tf(z,p,k)\nprint("pay, b:", b)\nprint("payda, a:",a)\n\nk = 5\nz = np.array([])\np = np.array([1.0/3])\nb,a =sgnl.zpk2tf(z,p,k)\nprint(
# ...

# %% [markdown]
# ### SORU-1

# %% [markdown]
# ## a)

# %% [markdown]
# ### a1)

# %% [markdown]
# #### Girişe dürtü işareti vererek;
# #### H(z) = [1 + (2z^-1)/3 + (z^-2)/9]  /  [1 - (z^-1)/2 + 4(z^-2) - 2(z^-3)]

# %% [markdown]
# ### a2)

# %% [markdown]
# #### Ters Z dönüşümü ile;
# #### H(z) = [1 + (2z^-1)/3 + (z^-2)/9]  /  [1 - (z^-1)/2 + 4(z^-2) - 2(z^-3)]

# %% [markdown]
# ### Yorum
# #### İki yöntemde birbirinin aynısı sayılır. İlkinde x[n] = dürtü işareti demek X(z)'yi 1 kabul etmek demek Y(z) bulunur.
# #### İkincisinde Y(z)/X(z) bulunur ve ilkiyle aynı çıkar X(z) = 1 gibi olur. İki yöntemde aynı sonuç vermiştir.

# %% [markdown]
# ## b)

# %%
# coding: utf-8

# In[ ]:

# Copyright (c) 2020 Hasan Huseyin Sonmez
#
# The following code implements a pole-zero diagram for discrete-time signal/systems
# It has been written to mimic the "zplane" function of Mathworks' MATLAB software.
# it is aimed as a supplementary tool to be used in
# ELM368 Fundamentals of Digital Signal Processing-laboratory course.
# Gebze Technical University, Kocaeli, Turkey
#
# The function parameters are:
#     Input:
#            b : the numerator coefficients of the discrete-time signal/system
#            a : the denominator coefficients of the discrete-time signal/system
#


# In[29]:

# import the necessary libraries
import numpy as np              # for using basic array functions
import matplotlib.pyplot as plt # for this example, it may not be necessary

# the main package for signal processing is called "scipy" and we will use "signal" sub-package
import scipy.signal as sgnl 
# alternative syntax: from scipy import signal as sgnl

def zplane(b,a):

	# Input: numerator and denominator coefficients:
	zeross,poless,k = sgnl.tf2zpk(b, a)
	if not zeross.size:
		zeross = np.zeros(len(poless))
		
	if not poless.size:
		poless = np.zeros(len(zeross))

	tol = 1e-4

	real_p = np.real(poless).copy()
	real_z = np.real(zeross).copy()
	imag_p = np.imag(poless).copy()
	imag_z = np.imag(zeross).copy()

	if not real_z.size:
		real_z[abs(real_z) < tol] = 0
	if not imag_z.size:
		imag_z[abs(imag_z) < tol] = 0
	if not real_p.size:
		real_p[abs(real_p) < tol] = 0
	if not imag_p.size:
		imag_p[abs(imag_p) < tol] = 0

	z = np.round(real_z,2) + 1j*np.round(imag_z,2)
	p = np.round(real_p,2) + 1j*np.round(imag_p,2)

	# plot the unit circle
	N = 128
	m = np.arange(0,N,1)
	unitCircle = np.exp(1j*m*2*np.pi/N)

	plt.figure()
	plt.plot(np.real(unitCircle), np.imag(unitCircle), 'b--', linewidth=0.3)
	plt.xlabel('Real Part'), plt.ylabel('Imaginary Part')

	# calculate the plot limits
	Cz, z_counts = np.unique(z, return_counts=True)
	Cp, p_counts = np.unique(p, return_counts=True)

	zz = [idx1 for idx1, valz in enumerate(z_counts) if valz > 1]
	pp = [idx2 for idx2, valp in enumerate(p_counts) if valp > 1]
	zval = z_counts[zz]
	pval = p_counts[pp]
	zs = Cz[zz]
	ps = Cp[pp]

	real_roots = np.concatenate((np.real(p),np.real(z)))
	imag_roots = np.concatenate((np.imag(p),np.imag(z)))

	# adjust plot limits
	xlower = min(-1, min(real_roots)) - 0.3
	xupper = max(1,  max(real_roots)) + 0.3
	ylower = min(-1, min(imag_roots)) - 0.3
	yupper = max(1,  max(imag_roots)) + 0.3
	plt.xlim(xlower, xupper), plt.ylim(ylower, yupper)

	# plot axes
	Xaxis = np.arange(xlower, xupper, 0.1)
	Yaxis = np.arange(ylower, yupper, 0.1)
	plt.plot(np.real(Xaxis), np.imag(Xaxis), 'b--', linewidth=0.3)
	plt.plot(np.imag(Yaxis), np.real(Yaxis), 'b--', linewidth=0.3)

	# plot poles and zeros
	plt.plot(np.real(z), np.imag(z), 'ro',  markerfacecolor = 'none')
	plt.plot(np.real(p), np.imag(p), 'rx')

	if zz:
		txtz = str(zval)[1:-1]
		plt.annotate(txtz, xy=(np.real(zs)+0.1,np.imag(zs)+0.1))
		
	if pp:
		txtp = str(pval)[1:-1]
		plt.annotate(txtp, xy=(np.real(ps)+0.1,np.imag(ps)+0.1))

	plt.grid()
	plt.show()


# In[ ]:


#####################################################333

import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sgnl
# %matplotlib notebook
#import zplane

b = np.array([1,2/3,1/9,0])
a = np.array([1,-1/2,4,-2])
z,p,k = sgnl.tf2zpk(b,a)

print("sıfırlar, z:", z)
print("\n")
print("kutuplar, p:", p)
print("\n")
print("kazanc,   k:", k)


zplane(b,a)
# Out:
# sıfırlar, z: [-0.33333333+3.16588799e-09j -0.33333333-3.16588799e-09j
#   0.        +0.00000000e+00j]
#
#
# kutuplar, p: [-2.47257828e-16+2.j -2.47257828e-16-2.j  5.00000000e-01+0.j]
#
#
# kazanc,   k: 1.0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## c)

# %% [markdown]
# #### c1)

# %% [markdown]
# #### kutup-sıfır diyagramına bakıldığında 3 adet kutup bulunmaktadır. Sistemin dürtü cevabının n<0 için 0 olduğu biliniyorsa
# #### sistem nedenseldir. Nedensel sistemler ise sağ yanlıdır. Yani en dıştaki kutbun dışarısı ROC'tur.
# #### En dıştaki kutuplar   -2.47257828e-16 + 2.j   ve    -2.47257828e-16-2.j 'dir.     ---------------->   ROC :  |Z|>|2j|

# %% [markdown]
# #### c2)

# %% [markdown]
# #### Sistemin fourier dönüşümünün olduğu biliniyorsa, ROC bölgesi birim çemberi içermelidir. -------->  ROC : |0.5|<|z|<|2j|

# %% [markdown]
# ## d)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sgnl
# %matplotlib notebook

#h[n] = 0.498*np.exp(-1j*0.183*np.pi)*(-2.473e-16+2j)**n*u_n+0.498*np.exp(1j*0.183*np.pi)*(-2.473e-16-2j)**n*u_n+0.163*(5e-01)**n*u_n

n = np.arange(0,31)
u_n = np.array([0 if i < 0 else 1 for i in n])


h_n = 0.498*np.exp(-1j*0.183*np.pi)*(-2.473e-16+2j)**n*u_n+0.498*np.exp(1j*0.183*np.pi)*(-2.473e-16-2j)**n*u_n+0.163*(5e-01)**n*u_n

plt.figure()
plt.stem(n,h_n)
plt.xlabel('n')
plt.title('h[n]')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'h[n]')

# %% [markdown]
# #### Bu sistemin çıkışından görüldüğü üzere n değerleri arttıkça h[n] de artmaktadır. Belli bir değerde sınırlanmamaktadır.
# #### Yani sistem kararsızdır.

# %% [markdown]
# ## e)

# %% [markdown]
# #### Bu sistem şuanki haliyle hem nedensel hem karalı olamaz. Nedensel olmanın şartı sağ yanlı olmaktır(en dıştaki kutbun
# #### dışarısı). Kararlılığın şartı ise birim çemberi içermektir. Birim çemberi içermesi istenirse sistemin çift yanlı olması
# #### gerekir.
# #### Sistem frekans uzayında ötelenirse sistem hem sağ yanlı hemde birim çemberi içerir hale gelebilir.
