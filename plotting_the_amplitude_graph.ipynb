# %%
'''
Abdülhalim YAYDEMİR
'''
import numpy as np
from matplotlib import pyplot as plt

pi = np.pi
a = -0.5
w = np.arange(0,2*pi)

X = 1/((1-2*a*np.cos(w)+a*a)**(1/2))

plt.plot(w,X)
plt.xlabel('w')
plt.title('|X(e^jw)| , w=[0,2pi)')
# Out:
# Text(0.5, 1.0, '|X(e^jw)| , w=[0,2pi)')
