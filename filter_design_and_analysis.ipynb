# %%
# Abdülhalim YAYDEMİR

# %%
import numpy as np
import scipy.signal as sgnl
import matplotlib.pyplot as plt
from scipy.fftpack import fft,ifft,fftshift,ifftshift
from scipy.io import loadmat
import SystemFunction
# %matplotlib notebook


'''
N=400
M=60
n=np.arange(0,M+1,1)
wn=0.54-0.46*np.cos(2*np.pi*n/M)

x1=wn*np.cos(0.2*np.pi*n)
x2=wn*np.cos(0.4*np.pi*n-np.pi/2)
x3=wn*np.cos(0.8*np.pi*n-np.pi/5)

xn=np.concatenate((x3,x1,x2,np.zeros(N-3*len(n))),axis=None)

plt.figure()
plt.plot(xn)


w=np.linspace(-np.pi,np.pi,N)
Xw=fft(xn)
Xw_shifted=np.fft.fftshift(Xw)

Hw,polezz,zerozz,K=SystemFunction.SystemFunction(w)

Hw_mag=abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))

fig, (ax1,ax2) = plt.subplots(2)
ax1.plot(w/np.pi,Hw_mag)
ax2.plot(w/np.pi,Hw_phs) , plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$ rad/sample')

tau_w=-np.diff(Hw_phs)*(N/(2*np.pi))
plt.figure()
plt.plot(w[1::]/np.pi, tau_w)
plt.ylabel('samples'), plt.xlabel('frequency x$\pi$ rad/sample')
plt.grid()
plt.show()

Yw_shifted=Hw*Xw_shifted
Yw=np.fft.ifftshift(Yw_shifted)
yn=np.real(ifft(Yw))

fig, (ax1,ax2) = plt.subplots(2)
ax1.plot(xn)
ax2.plot(yn)

####################################3

N=40
hn=np.ones(5)
Hw=np.fft.fftshift(fft(hn,N))
w=np.linspace(-np.pi,np.pi,N)
Hw_mag=abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))

fig,(ax1,ax2)= plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag)
ax2.plot(w/np.pi, Hw_phs), plt.ylabel('phase (rad)'), plt.xlabel('frequency rad/sample')

tau_w=-np.diff(Hw_phs)*(N/(2*np.pi))
plt.figure()
plt.plot(w[1::]/np.pi, tau_w)
plt.ylabel('group delay (samples)'), plt.xlabel('frequency rad/sample')


n=np.arange(0,N,1)
w0=0.1*np.pi
xn=np.cos(w0*n)
Xw=np.fft.fftshift(fft(xn,N))

Yw_shifted=Hw*Xw
Yw=np.fft.ifftshift(Yw_shifted)
yn=np.real(ifft(Yw))

fig,(ax1,ax2)=plt.subplots(2)
ax1.stem(n,xn), ax1.title.set_text('input signal')
ax2.stem(n,yn), ax2.title.set_text('output signal')
##########################################

filter_data=loadmat('butterworth.mat')
Coeffs=filter_data['ba'].astype(np.float)
b=Coeffs[:,0]
a=Coeffs[:,1]

w,Hw=sgnl.freqz(b,a)
Hw_mag=abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))

fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag)
ax2.plot(w/np.pi,Hw_phs), plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$ rad/sample')

Coeffs.shape

n,hn=sgnl.dimpulse((b,a,1), n=100)
plt.figure()
plt.plot(n,np.squeeze(hn))

N=400
M=60
n1=np.arange(0,M+1,1)
wn=0.54-0.46*np.cos(2*np.pi*n1/M)

x1=wn*np.cos(0.2*np.pi*n1)
x2=wn*np.cos(0.4*np.pi*n1-np.pi/2)
x3=wn*np.cos(0.8*np.pi*n1-np.pi/5)

xn=np.concatenate((x3,x1,x2,np.zeros(N-3*len(n1))),axis=None)

plt.figure()
plt.plot(xn)


yn=sgnl.lfilter(b,a,xn)
plt.figure()
plt.plot(yn)

'''
# Out:
# "\nN=400\nM=60\nn=np.arange(0,M+1,1)\nwn=0.54-0.46*np.cos(2*np.pi*n/M)\n\nx1=wn*np.cos(0.2*np.pi*n)\nx2=wn*np.cos(0.4*np.pi*n-np.pi/2)\nx3=wn*np.cos(0.8*np.pi*n-np.pi/5)\n\nxn=np.concatenate((x3,x1,x2,np.zeros(N-3*len(n))),axis=None)\n\nplt.figure()\nplt.plot(xn)\n\n\nw=np.linspace(-np.pi,np.pi,N)\nXw=fft(xn)\nXw_shifted=np.fft.fftshift(Xw)\n\nHw,polezz,zerozz,K=SystemFunction.SystemFunction(w)\n\nHw_mag=abs(Hw)\nHw_phs=np.unwrap(np.angle(Hw))\n\nfig, (ax1,ax2) = plt.subplots(2)\nax1.plot(w/np.pi,Hw_mag)\nax2.plot(w/np.pi,Hw_phs) , plt.ylabel('degrees')\nplt.xlabel('frequency x$\\pi$ rad/sample')\n\ntau_w=-np.diff(Hw_phs)*(N/(2*np.pi))\nplt.figure()\nplt.plot(w[1::]/np.pi, tau_w)\nplt.ylabel('samples'), plt.xlabel('frequency x$\\pi$ rad/sample')\nplt.grid()\nplt.show()\n\nYw_shifted=Hw*Xw_shifted\nYw=np.fft.ifftshift(Yw_shifted)\nyn=np.real(ifft(Yw))\n\nfig, (ax1,ax2) = plt.subplots(2)\nax1.plot(xn)\nax2.plot(yn)\n\n####################################3\n\nN=40\nhn=np.ones(5)\nHw=np.
# ...

# %% [markdown]
# ### #####################

# %% [markdown]
# ### SORU-1

# %%
import numpy as np
import scipy.signal as sgnl
import matplotlib.pyplot as plt
from scipy.fftpack import fft,ifft,fftshift,ifftshift
from scipy.io import loadmat
# %matplotlib notebook
import SystemFunction


N=400
w=np.linspace(-np.pi,np.pi,N)

# %% [markdown]
# ## FIR LOWPASS BLACKMANHARRİS

# %%
b=np.array([-7.016675883563814e-22,-5.82758791386992e-06,-3.0124972394779912e-05,-2.832596955243285e-05,0.00012842255367258215,0.0004612465906095025,0.0005237479974547035,-0.0004960875523511745,-0.0025987159074662087,-0.003588894769440459,2.5431941739976616e-18,0.00845420799494669,0.014602624762883487,0.006827081003955228,-0.018428845313445186,-0.044293511370316146,-0.037130960290580856,0.028810073967302893,0.1429343174780504,0.2538602857145463,0.2999985713400787,0.2538602857145463,0.1429343174780504,0.028810073967302893,-0.037130960290580856,-0.044293511370316146,-0.018428845313445186,0.006827081003955228,0.014602624762883487,0.00845420799494669,2.5431941739976616e-18,-0.003588894769440459,-0.0025987159074662087,-0.0004960875523511745,0.0005237479974547035,0.0004612465906095025,0.00012842255367258215,-2.832596955243285e-05,-3.0124972394779912e-05,-5.82758791386992e-06,-7.016675883563814e-22])

w,Hw=sgnl.freqz(b,1)
Hw_mag=abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))

fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag)
plt.title('magnitude')
ax2.plot(w/np.pi,Hw_phs)
plt.title('degrees')
plt.xlabel('frequency x$\pi$ rad/sample')
plt.show()

tau_w=-np.diff(Hw_phs)*(N/(2*np.pi))
plt.figure()
plt.plot(w[1::]/np.pi, tau_w)
plt.title('group delay (samples)'), plt.xlabel('frequency rad/sample')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (Text(0.5, 1.0, 'group delay (samples)'), Text(0.5, 0, 'frequency rad/sample'))

# %%
#Burada FIR lowpass filtre blackmanharris yöntemiyle tasarlanmıştır.
# Kesim frekansı 0.3pi dir.
# faz fır olduğundan geçiren kısımda doğrusaldır.
# grup gecikmesi sabittir.

# %% [markdown]
# ## FIR LOWPASS HAMMİNG

# %%
b=np.array([-9.374889635572227e-19,-0.0011634379762831223,-0.0017276711494943853,-0.000754533106814873,0.0019668433227974288,0.004566119955030273,0.0036106456235418614,-0.002510884218864423,-0.010057519765528818,-0.01097974201828738,6.328050504011249e-18,0.017546162120233834,0.025866573529965534,0.010544230581595378,-0.025322167145666437,-0.0551982450816534,-0.0427531371097064,0.0312080153668508,0.1482623723675855,0.25658729973388633,0.30061814994162467,0.25658729973388633,0.1482623723675855,0.0312080153668508,-0.0427531371097064,-0.0551982450816534,-0.025322167145666437,0.010544230581595378,0.025866573529965534,0.017546162120233834,6.328050504011249e-18,-0.01097974201828738,-0.010057519765528818,-0.002510884218864423,0.0036106456235418614,0.004566119955030273,0.0019668433227974288,-0.000754533106814873,-0.0017276711494943853,-0.0011634379762831223,-9.374889635572227e-19])

w,Hw=sgnl.freqz(b,1)
Hw_mag=abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))

fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag)
plt.title('magnitude')
ax2.plot(w/np.pi,Hw_phs)
plt.title('degrees')
plt.xlabel('frequency x$\pi$ rad/sample')
plt.show()

tau_w=-np.diff(Hw_phs)*(N/(2*np.pi))
plt.figure()
plt.plot(w[1::]/np.pi, tau_w)
plt.title('group delay (samples)'), plt.xlabel('frequency rad/sample')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (Text(0.5, 1.0, 'group delay (samples)'), Text(0.5, 0, 'frequency rad/sample'))

# %%
#Burada FIR lowpass filtre hamming yöntemiyle tasarlanmıştır.
# genlikte geçiren kısım blackmanharrise göre biraz daha keskindir
# Kesim frekansı 0.3pi dir.
# faz fır olduğundan geçiren kısımda doğrusaldır.
# grup gecikmesi sabittir.

# %% [markdown]
# ## FIR BANDPASS BLACKMANHARRİS

# %%
b=np.array([-7.036092003859834e-22,-1.0259837562863572e-06,4.8878108555044045e-05,8.24326385509489e-05,-0.0003371449631323489,-0.0004625229242235971,0.00032458977056472175,-0.0004487654160042536,0.0009953678706394848,0.007829499134479508,-7.650694640396861e-18,-0.018443620788988684,-0.005593140625421583,0.006175841002891981,-0.011421169534077777,0.044416077690803295,0.09747911001795681,-0.08384145190782379,-0.23191254731718444,0.04469371090729278,0.30082870920684507,0.04469371090729278,-0.23191254731718444,-0.08384145190782379,0.09747911001795681,0.044416077690803295,-0.011421169534077777,0.006175841002891981,-0.005593140625421583,-0.018443620788988684,-7.650694640396861e-18,0.007829499134479508,0.0009953678706394848,-0.0004487654160042536,0.00032458977056472175,-0.0004625229242235971,-0.0003371449631323489,8.24326385509489e-05,4.8878108555044045e-05,-1.0259837562863572e-06,-7.036092003859834e-22])

w,Hw=sgnl.freqz(b,1)
Hw_mag=abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))

fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag)
plt.title('magnitude')
ax2.plot(w/np.pi,Hw_phs)
plt.title('degrees')
plt.xlabel('frequency x$\pi$ rad/sample')
plt.show()

tau_w=-np.diff(Hw_phs)*(N/(2*np.pi))
plt.figure()
plt.plot(w[1::]/np.pi, tau_w)
plt.title('group delay (samples)'), plt.xlabel('frequency rad/sample')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (Text(0.5, 1.0, 'group delay (samples)'), Text(0.5, 0, 'frequency rad/sample'))

# %%
#Burada FIR bandpass filtre blackmanharris yöntemiyle tasarlanmıştır.
# Kesim frekansı 0.3pi ve 0.6pi dir.
# faz fır olduğundan geçiren kısımda doğrusaldır.
# grup gecikmesi sabittir.

# %% [markdown]
# ## FIR BANDPASS HAMMİNG

# %%
b=np.array([-9.341825115234416e-19,-0.00020354496409748568,0.002785571370714781,0.002182017315649868,-0.005131101613138855,-0.004550015598393885,0.0022236313804132437,-0.0022571125374577406,0.0038280815695599228,0.023802954541225337,-1.8917195858349675e-17,-0.03803827982709204,-0.009845305374104827,0.0094785394184077,-0.0155947637502953,0.055003565083481636,0.11153440045155795,-0.09024975750234802,-0.23904747147179367,0.04489027672885139,0.2995578926672409,0.04489027672885139,-0.23904747147179367,-0.09024975750234802,0.11153440045155795,0.055003565083481636,-0.0155947637502953,0.0094785394184077,-0.009845305374104827,-0.03803827982709204,-1.8917195858349675e-17,0.023802954541225337,0.0038280815695599228,-0.0022571125374577406,0.0022236313804132437,-0.004550015598393885,-0.005131101613138855,0.002182017315649868,0.002785571370714781,-0.00020354496409748568,-9.341825115234416e-19])
w,Hw=sgnl.freqz(b,1)
Hw_mag=abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))

fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag)
plt.title('magnitude')
ax2.plot(w/np.pi,Hw_phs)
plt.title('degrees')
plt.xlabel('frequency x$\pi$ rad/sample')
plt.show()

tau_w=-np.diff(Hw_phs)*(N/(2*np.pi))
plt.figure()
plt.plot(w[1::]/np.pi, tau_w)
plt.title('group delay (samples)'), plt.xlabel('frequency rad/sample')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (Text(0.5, 1.0, 'group delay (samples)'), Text(0.5, 0, 'frequency rad/sample'))

# %%
#Burada FIR bandpass filtre hamming yöntemiyle tasarlanmıştır.
# genlikte geçiren kısım blackmanharrise göre biraz daha keskindir
# Kesim frekansı 0.3pi ve 0.6pi dir.
# faz fır olduğundan geçiren kısımda doğrusaldır.
# grup gecikmesi sabittir.

# %% [markdown]
# ### SORU-2

# %%
import numpy as np
import scipy.signal as sgnl
import matplotlib.pyplot as plt
from scipy.fftpack import fft,ifft,fftshift,ifftshift
from scipy.io import loadmat
# %matplotlib notebook
import SystemFunction


N=400
w=np.linspace(-np.pi,np.pi,N)

# %% [markdown]
# ## IIR LOWPASS BUTTERWORTH

# %%
b=np.array([9.294367977145108e-10,1.9518172752004726e-08,1.9518172752004726e-07,1.2361509409602993e-06,5.562679234321347e-06,1.8913109396692578e-05,5.043495839118021e-05,0.00010807491083824331,0.0001891310939669258,0.00027318935795222614,0.0003278272295426714,0.0003278272295426714,0.00027318935795222614,0.0001891310939669258,0.00010807491083824331,5.043495839118022e-05,1.891310939669258e-05,5.562679234321348e-06,1.2361509409602995e-06,1.9518172752004726e-07,1.9518172752004726e-08,9.294367977145108e-10])
a=np.array([1.0,-8.394083058269654,35.54294728959951,-99.77098932643086,206.77150061395508,-334.6931529147318,437.52436813025804,-471.8034433288915,425.46773079737943,-323.62659230632937,208.62105078409928,-114.15670536512569,52.955901578169694,-20.738054601294408,6.80473012568707,-1.8494321526696018,0.4093390594092455,-0.07196102785643202,0.009673268265183714,-0.000934469967042496,5.779476236487671e-05,-1.7197793610278534e-06])


w,Hw=sgnl.freqz(b,a)

Hw_mag=abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))

fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag), plt.ylabel('magnitude')
ax2.plot(w/np.pi,Hw_phs), plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$ rad/sample')
plt.show()

tau_w=-np.diff(Hw_phs)*(N/(2*np.pi))
plt.figure()
plt.plot(w[1::]/np.pi, tau_w)
plt.ylabel('group delay (samples)'), plt.xlabel('frequency rad/sample')
Hw
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# array([ 1.00000000e+00+0.00000000e+00j,  9.96755720e-01-8.04862366e-02j,
#         9.87043373e-01-1.60453667e-01j,  9.70924318e-01-2.39386652e-01j,
#         9.48500423e-01-3.16775863e-01j,  9.19913478e-01-3.92121402e-01j,
#         8.85344367e-01-4.64935858e-01j,  8.45012020e-01-5.34747310e-01j,
#         7.99172138e-01-6.01102232e-01j,  7.48115700e-01-6.63568308e-01j,
#         6.92167262e-01-7.21737128e-01j,  6.31683059e-01-7.75226749e-01j,
#         5.67048907e-01-8.23684124e-01j,  4.98677932e-01-8.66787356e-01j,
#         4.27008125e-01-9.04247788e-01j,  3.52499739e-01-9.35811912e-01j,
#         2.75632548e-01-9.61263074e-01j,  1.96902968e-01-9.80422981e-01j,
#         1.16821069e-01-9.93152978e-01j,  3.59074842e-02-9.99355118e-01j,
#        -4.53097648e-02-9.98972985e-01j, -1.26298505e-01-9.91992282e-01j,
# ...

# %%
#Burada IIR lowpass filtre butterworth yöntemiyle tasarlanmıştır.
# Kesim frekansı 0.3pi dir.
# faz ıır olduğundan doğrusal değildir ama doğrusala yakındır
#grup gecikmesi sabit değildir.
# grup gecikmesi kesim frekansı civarında ve yuksek frekanslarda mevcuttur.
#Yuksek freakanstaki gecikmeler geçirilmediğinden önemsizdir.

# %% [markdown]
# ## IIR LOWPASS CHEBYSHEV1

# %%
b=np.array([1.4938842180465853e-13,3.1371568578978297e-12,3.1371568578978295e-11,1.9868660100019587e-10,8.940897045008814e-10,3.039904995302996e-09,8.10641332080799e-09,1.7370885687445693e-08,3.039904995302996e-08,4.390973882104328e-08,5.269168658525193e-08,5.269168658525192e-08,4.3909738821043267e-08,3.039904995302996e-08,1.7370885687445693e-08,8.10641332080799e-09,3.039904995302996e-09,8.940897045008814e-10,1.9868660100019584e-10,3.1371568578978295e-11,3.1371568578978297e-12,1.4938842180465853e-13])
a=np.array([1.0,-15.967142244306636,124.95497542076299,-636.546979106256,2365.505776978732,-6812.89345057495,15774.773226571857,-30067.87787544149,47926.37750259647,-64542.85399087565,73898.5859683901,-72146.02590201829,60055.305828869234,-42493.9618514317,25396.477006526282,-12687.132153931976,5214.480198984514,-1721.7208868399564,440.1793147162896,-82.00144039247499,9.930249461608499,-0.5883753455139189])


w,Hw=sgnl.freqz(b,a)

Hw_mag=abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))

fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag), plt.ylabel('magnitude')
ax2.plot(w/np.pi,Hw_phs), plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$ rad/sample')
plt.show()

tau_w=-np.diff(Hw_phs)*(N/(2*np.pi))
plt.figure()
plt.plot(w[1::]/np.pi, tau_w)
plt.ylabel('group delay (samples)'), plt.xlabel('frequency rad/sample')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (Text(0, 0.5, 'group delay (samples)'), Text(0.5, 0, 'frequency rad/sample'))

# %%
#Burada IIR lowpass filtre chebyshev yöntemiyle tasarlanmıştır.
# genlikte geçiren kısım sabit değildir dalgalıdır
# Kesim frekansı 0.3pi dir.
# faz ıır olduğundan doğrusal değildir. butterwortha göre daha bozuktur.
#grup gecikmesi sabit değildir.
# grup gecikmesi kesim frekansına kadar ve yuksek frekanslarda mevcuttur.
#Yuksek freakanstaki gecikmeler geçirilmediğinden önemsizdir.

# %% [markdown]
# ## IIR HIGHPASS BUTTERWORTH

# %%
b=np.array([9.294367977145126e-10,-1.951817275200477e-08,1.9518172752004768e-07,-1.2361509409603018e-06,5.5626792343213575e-06,-1.891310939669262e-05,5.043495839118031e-05,-0.00010807491083824354,0.00018913109396692622,-0.00027318935795222674,0.0003278272295426721,-0.000327827229542672,0.00027318935795222674,-0.0001891310939669262,0.00010807491083824354,-5.0434958391180326e-05,1.891310939669262e-05,-5.562679234321359e-06,1.2361509409603023e-06,-1.9518172752004773e-07,1.951817275200477e-08,-9.294367977145126e-10])
a=np.array([1.0,8.394083058269652,35.54294728959949,99.77098932643078,206.7715006139548,334.69315291473134,437.52436813025736,471.8034433288906,425.46773079737864,323.62659230632863,208.62105078409874,114.15670536512539,52.955901578169545,20.738054601294344,6.804730125687048,1.8494321526695956,0.409339059409244,0.07196102785643177,0.009673268265183678,0.0009344699670424924,5.779476236487648e-05,1.7197793610278473e-06])


w,Hw=sgnl.freqz(b,a)

Hw_mag=abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))

fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag), plt.ylabel('magnitude')
ax2.plot(w/np.pi,Hw_phs), plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$ rad/sample')
plt.show()

tau_w=-np.diff(Hw_phs)*(N/(2*np.pi))
plt.figure()
plt.plot(w[1::]/np.pi, tau_w)
plt.ylabel('group delay (samples)'), plt.xlabel('frequency rad/sample')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (Text(0, 0.5, 'group delay (samples)'), Text(0.5, 0, 'frequency rad/sample'))

# %%
#Burada IIR hıghpass filtre butterworth yöntemiyle tasarlanmıştır.
# Kesim frekansı 0.7pi dir.
# faz ıır olduğundan doğrusal değildir ama doğrusala yakındır
#grup gecikmesi sabit değildir.
# grup gecikmesi kesim frekansı civarında ve dusuk frekanslarda mevcuttur.
#dusuk freakanstaki gecikmeler geçirilmediğinden önemsizdir.

# %% [markdown]
# ## IIR HIGHPASS CHEBYSHEV1

# %%
b=np.array([1.493884218046589e-13,-3.1371568578978374e-12,3.137156857897837e-11,-1.9868660100019634e-10,8.940897045008836e-10,-3.0399049953030044e-09,8.106413320808012e-09,-1.737088568744574e-08,3.039904995303004e-08,-4.39097388210434e-08,5.2691686585252073e-08,-5.2691686585252073e-08,4.390973882104339e-08,-3.039904995303004e-08,1.7370885687445736e-08,-8.106413320808009e-09,3.0399049953030035e-09,-8.940897045008834e-10,1.9868660100019634e-10,-3.137156857897837e-11,3.1371568578978374e-12,-1.493884218046589e-13])
a=np.array([1.0,15.967142244306633,124.95497542076296,636.5469791062559,2365.505776978732,6812.893450574949,15774.773226571851,30067.877875441474,47926.37750259644,64542.85399087562,73898.58596839008,72146.02590201827,60055.30582886921,42493.961851431675,25396.47700652627,12687.132153931969,5214.480198984512,1721.7208868399557,440.17931471628924,82.00144039247493,9.930249461608492,0.5883753455139186])


w,Hw=sgnl.freqz(b,a)

Hw_mag=abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))

fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag), plt.ylabel('magnitude')
ax2.plot(w/np.pi,Hw_phs), plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$ rad/sample')
plt.show()

tau_w=-np.diff(Hw_phs)*(N/(2*np.pi))
plt.figure()
plt.plot(w[1::]/np.pi, tau_w)
plt.ylabel('group delay (samples)'), plt.xlabel('frequency rad/sample')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (Text(0, 0.5, 'group delay (samples)'), Text(0.5, 0, 'frequency rad/sample'))

# %%
#Burada IIR hıghpass filtre chebyshev yöntemiyle tasarlanmıştır.
# genlikte geçiren kısım sabit değildir dalgalıdır
# Kesim frekansı 0.7pi dir.
# faz ıır olduğundan doğrusal değildir ama butterwortha göre daha bozuktur.
#grup gecikmesi sabit değildir.
# grup gecikmesi kesim frekansından sonra ve dusuk frekanslarda mevcuttur.
#dusuk freakanstaki gecikmeler geçirilmediğinden önemsizdir.
